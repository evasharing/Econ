# %% [markdown]
# ### Intro

# %%
! pip install db-sqlite3

# %%
import pandas as pd
import sqlite3
from datetime import date

# %%
# Connect with the database
# Out:
#   File "<ipython-input-3-a194dfacd777>", line 2
#     CREATE DATABASE giraffe_db;
#                   ^
# SyntaxError: invalid syntax
