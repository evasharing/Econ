# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Reference

# %% [markdown]
# https://github.com/tudev/Workshops-2020-2021/blob/master/Google%20Colab%20Tutorials/Google_Colab_%2B_Git_Pushing_Changes_to_a_GitHub_Repo!.ipynb
#
# https://www.youtube.com/watch?v=eLhy3_d2UPo

# %% [markdown]
# ### Github Setup

# %%
# !git config --global user.name "evasharing"
# !git config --global user.email "eva68866653@gmail.com"
# !git config --global user.password "Evaguangyi05040607"

# %% [markdown]
# ### Github to Colab

# %%
# Set the Repo: Econ
token = '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'
username = 'evasharing'
repo = 'Econ'

# %%
# Clone the Repo(so the folder in Github can be connected to)
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# fatal: destination path 'Econ' already exists and is not an empty directory.

# %% [markdown]
# ### Colab to Github Workflow

# %%
# %cd /content/gdrive/My Drive/#add your custom working directory

# %%
# Check the current directary(where are we)
# !pwd
# Out:
# /content

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# Move the Current File to folder Wanted(using copy path)
# !mv /content/gdrive/MyDrive/Colab_Notebooks/00_My_Github_Setup.ipynb /content/Econ
# Out:
# mv: cannot stat '/content/gdrive/MyDrive/Colab_Notebooks/00_My_Github_Setup.ipynb': No such file or directory

# %%
# !git remote add origin https://{github_username}:{github_password}@github.com/{github_username}/{github_repo_name}.git
# !git remote -v
# Out:
# origin	https://{github_username}:{github_password}@github.com/{github_username}/{github_repo_name}.git (fetch)
# origin	https://{github_username}:{github_password}@github.com/{github_username}/{github_repo_name}.git (push)

# %%
# !git config --global user.email '{user_email}'
# !git config --global user.name '{user_name}'

# %%
# !git add .
# !git commit -m 'First commit'

# %%
# !git push origin master
